# %% [markdown]
# <a href="https://colab.research.google.com/github/elisamsp/DO101-apps/blob/python_portfolio/Fundamentos_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fundamentos de Python
# ##Un curso enfocado en automatización
# Alumno => Minerva Sanchez

# %%
#Variables con listas de nombres de mujeres y hombres
female_name = ['Elisa','Minerva','Diana','Esmeralda','Gloria','Fatima','Isabel','Rosa']
male_name = ['Jose','Manuel','Alejandro','Ernesto','Luis','Jesus','Christian','Fernando']

#Creación de variable con para for
login_r = "exitoso"

#Creación de variable name y solicitud del valor
name = input("Hola, ¿Cual es tu nombre? ")

#Validación del nombre para definir el prefijo del saludo
if name in female_name:
  prefijo = "amiga"
elif name in male_name:
  prefijo = "amigo"
else:
  prefijo = ""

#Respuesta con saludo reconociendo el nombre y el prefijo
print("Hola", prefijo, name)

#Inicio de la creación de la cuenta
registro=input("¿Quieres crear una cuenta? ")

#Validación del registro
if registro == "Si":
  #cuando la respuesta es si, entonces se solicitan todos los valores
  print("---------------------------------------")
  print("Registra los siguientes datos: ")
  for respuesta in "Si":
    sexo = input("¿Cuál es tu sexo? ")
    edad = input("¿Cuál es tu edad? ")
    mail = input("¿Cuál es tu mail? ")
    usuario = input("Registra tu usuario? ")
    contraseña = input("Registra tu contraseña? ")
    print("---------------------------------------")
    print("Revisa si los datos son correctos: ")
    print("Sexo: ", sexo)
    print("Edad: ", edad)
    print("Mail: ", mail)
    print("Usuario: ", usuario)
    print("Contraseña: ", contraseña)
    print("---------------------------------------")
    respuesta = input("¿Son los datos correctos? ")
    if respuesta == "Si":
      print("Tu registro ha sido exitoso")
      print("Valida tu ingreso")
      for login in login_r:
        user = input("Ingresa tu usuario: ")
        pwd = input("Ingresa tu contraseña: ")
        if user == user and pwd == contraseña:
          login = "exitoso"
          print("Log in ", login)
          print("Gracias por tu visita ", name)
          break
        else:
          print("Vuelve a intentarlo")
    else:
      print("Registra los valores correctos")
else:
  print("Gracias por tu visita", name)
# Out:
# Hola, ¿Cual es tu nombre? Luis
# Hola amigo Luis
# ¿Quieres crear una cuenta? No
# Gracias por tu visita Luis
